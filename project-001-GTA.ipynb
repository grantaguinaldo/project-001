# %%
#Standard imports 

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json
import requests as r
import squarify
from scipy.stats import ttest_ind_from_stats
# %matplotlib inline

# %%
#Reference file path

# Download file from:  https://enveraconsulting.box.com/s/c3t6elxu7ngj3ywfs6to2a75arfsbgkv

file = '/Users/gta/Desktop/globalterrorismdb_0617dist.csv'
presidents = 'http://bit.ly/001-presidents'
gdp_filepath = 'http://bit.ly/001-gdp'
country_codes = 'http://bit.ly/001-codes'

# %%
#Read CSV into dataframe.  Forced encoding to 'cp1252 due to error.

df = pd.read_csv(file, encoding='cp1252', low_memory=False, skipinitialspace=True)
df_presidents = pd.read_csv(presidents, skipinitialspace=True)
df_gdp = pd.read_csv(gdp_filepath, skipinitialspace=True)
df_codes = pd.read_csv(country_codes, skipinitialspace=True)

# %%
df.shape
# Out:
# (170350, 135)

# %%
#Select a portion of the columns and send them to a new dataframe

df = df[['iyear',
 'imonth',
 'iday',
 'country_txt',
 'region_txt',
 'city',
 'latitude',
 'longitude',
 'location',
 'success',
 'suicide',
 'attacktype1_txt',
 'targtype1_txt',
 'natlty1_txt',
 'gname',
 'weaptype1_txt',
 'nkill',
 'nwound']]

# %%
#Generate dictionary needed to rename columns

col_name = {'iyear': 'year',
 'imonth': 'month',
 'iday': 'day',
 'country_txt': 'country',
 'region_txt': 'region',
 'city': 'city',
 'latitude': 'latitude',
 'longitude': 'longitude',
 'location': 'location',
 'success': 'success',
 'suicide': 'sucide',
 'attacktype1_txt': 'type_of_attack',
 'targtype1_txt': 'type_of_target',
 'natlty1_txt': 'nationality',
 'gname': 'group_name',
 'weaptype1_txt': 'type_of_weapon',
 'nkill': 'num_killed',
 'nwound': 'num_wounded'}

#Rename columns based on dict and display head

df = df.rename(columns=col_name)
df.columns.tolist()
# Out:
# ['year',
#  'month',
#  'day',
#  'country',
#  'region',
#  'city',
#  'latitude',
#  'longitude',
#  'location',
#  'success',
#  'sucide',
#  'type_of_attack',
#  'type_of_target',
#  'nationality',
#  'group_name',
#  'type_of_weapon',
#  'num_killed',
#  'num_wounded']

# %%
df['num_killed'].fillna(value = 0, inplace=True)
df['num_wounded'].fillna(value = 0, inplace=True)

# %%
df['num_killed_wounded'] = df['num_killed'] + df['num_wounded']

# %%
df_presidents.columns.tolist()
# Out:
# ['year', 'president', 'party']

# %%
col_name = {'country_code': 'country'}
df_gdp = df_gdp.rename(columns=col_name)
df_gdp.columns.tolist()
# Out:
# ['country', 'country_name', 'gdp_value', 'gdp_year']

# %%
col_name = {'Name': 'country', 'Code': 'code'}
df_codes = df_codes.rename(columns=col_name)
df_codes.columns.tolist()
# Out:
# ['country', 'code']

# %%
df_president_main = pd.merge(df, df_presidents, on='year', how='inner')

# %%
df_president_main_codes = pd.merge(df_president_main, df_codes, on='country', how='inner')

# %%
df_president_main_codes['helper'] = df_president_main_codes['code'] + df_president_main_codes['year'].map(str)

# %%
df_gdp['helper'] = df_gdp['country'] + df_gdp['gdp_year'].map(str)

# %%
df_gdp.columns.tolist()
# Out:
# ['country', 'country_name', 'gdp_value', 'gdp_year', 'helper']

# %%
df_gdp = df_gdp.drop(['country'], axis = 1)

# %%
df_gdp.columns.tolist()
# Out:
# ['country_name', 'gdp_value', 'gdp_year', 'helper']

# %%
df_combined = pd.merge(df_president_main_codes, df_gdp, on='helper', how='inner')

# %%
df_combined = df_combined.drop(['gdp_year'], axis = 1)

# %%
df_combined['party'] = df_combined['party'].str.strip()

# %%
df_combined.shape
# Out:
# (160125, 25)

# %%
df_year_total = df_combined[['year', 'success']].groupby('year', as_index = False).sum()
plt.figure(figsize = (15, 6))
x = df_year_total['year']
y = df_year_total['success']
plt.bar(x, y)
plt.xlabel('Year', fontsize = 14)
plt.ylabel('Number of Successful Attacks', fontsize = 14)
plt.title('Number of Successful Attacks From 1970 to 2016', fontsize = 14)
plt.show()

# %%
df_1 = df_combined[df_combined['region'] == 'Australasia & Oceania'][['year', 'success']].groupby('year', as_index = False).sum()
df_2 = df_combined[df_combined['region'] == 'Central America & Caribbean'][['year', 'success']].groupby('year', as_index = False).sum()

plt.figure(figsize = (7, 7))
x = df_1['year']
y = df_1['success']
plt.subplot(1, 2, 1)
plt.bar(x, y)
plt.title('Australasia & Oceania')
plt.xlabel('Year')
plt.ylabel('Number of Successful Attacks')

x1 = df_2['year']
y1 = df_2['success']
plt.subplot(1, 2, 2)
plt.bar(x1, y1)
plt.title('Central America & Caribbean')
plt.xlabel('Year')
plt.ylabel('Number of Successful Attacks')

plt.tight_layout()
plt.show()

# %%
df_3 = df_combined[df_combined['region'] == 'Western Europe'][['year', 'success']].groupby('year', as_index = False).sum()
df_4 = df_combined[df_combined['region'] == 'Eastern Europe'][['year', 'success']].groupby('year', as_index = False).sum()

plt.figure(figsize = (7, 7))
x = df_3['year']
y = df_3['success']
plt.subplot(1, 2, 1)
plt.bar(x, y)
plt.title('Western Europe')
plt.xlabel('Year')
plt.ylabel('Number of Successful Attacks')

x1 = df_4['year']
y1 = df_4['success']
plt.subplot(1, 2, 2)
plt.bar(x1, y1)
plt.title('Eastern Europe')
plt.xlabel('Year')
plt.ylabel('Number of Successful Attacks')

plt.tight_layout()
plt.show()

# %%
df_5 = df_combined[df_combined['region'] == 'South America'][['year', 'success']].groupby('year', as_index = False).sum()
df_6 = df_combined[df_combined['region'] == 'North America'][['year', 'success']].groupby('year', as_index = False).sum()

plt.figure(figsize = (7, 7))
x = df_5['year']
y = df_5['success']
plt.subplot(1, 2, 1)
plt.bar(x, y)
plt.title('South America')
plt.xlabel('Year')
plt.ylabel('Number of Successful Attacks')

x1 = df_6['year']
y1 = df_6['success']
plt.subplot(1, 2, 2)
plt.bar(x1, y1)
plt.title('North America')
plt.xlabel('Year')
plt.ylabel('Number of Successful Attacks')

plt.tight_layout()
plt.show()

# %%
df_7 = df_combined[df_combined['region'] == 'Middle East & North Africa'][['year', 'success']].groupby('year', as_index = False).sum()
df_8 = df_combined[df_combined['region'] == 'Sub-Saharan Africa'][['year', 'success']].groupby('year', as_index = False).sum()

plt.figure(figsize = (7, 7))
x = df_7['year']
y = df_7['success']
plt.subplot(1, 2, 1)
plt.bar(x, y)
plt.title('Middle East & North Africa')
plt.xlabel('Year')
plt.ylabel('Number of Successful Attacks')

x1 = df_8['year']
y1 = df_8['success']
plt.subplot(1, 2, 2)
plt.bar(x1, y1)
plt.title('Sub-Saharan Africa')
plt.xlabel('Year')
plt.ylabel('Number of Successful Attacks')

plt.tight_layout()
plt.show()

# %%
df_9 = df_combined[df_combined['region'] == 'Central Asia'][['year', 'success']].groupby('year', as_index = False).sum()
df_10 = df_combined[df_combined['region'] == 'East Asia'][['year', 'success']].groupby('year', as_index = False).sum()

plt.figure(figsize = (7, 7))
x = df_9['year']
y = df_9['success']
plt.subplot(1, 2, 1)
plt.bar(x, y)
plt.title('Central Asia')
plt.xlabel('Year')
plt.ylabel('Number of Successful Attacks')

x1 = df_10['year']
y1 = df_10['success']
plt.subplot(1, 2, 2)
plt.bar(x1, y1)
plt.title('East Asia')
plt.xlabel('Year')
plt.ylabel('Number of Successful Attacks')

plt.tight_layout()
plt.show()

# %%
df_11 = df_combined[df_combined['region'] == 'South Asia'][['year', 'success']].groupby('year', as_index = False).sum()
df_12 = df_combined[df_combined['region'] == 'Southeast Asia'][['year', 'success']].groupby('year', as_index = False).sum()

plt.figure(figsize = (7, 7))
x = df_11['year']
y = df_11['success']
plt.subplot(1, 2, 1)
plt.bar(x, y)
plt.title('South Asia')
plt.xlabel('Year')
plt.ylabel('Number of Successful Attacks')

x1 = df_12['year']
y1 = df_12['success']
plt.subplot(1, 2, 2)
plt.bar(x1, y1)
plt.title('Southeast Asia')
plt.xlabel('Year')
plt.ylabel('Number of Successful Attacks')

plt.tight_layout()
plt.show()

# %%
new_df = df_combined[['region', 'year', 'success']].groupby(['region', 'year'], as_index=False).sum()
region_list = set(new_df.region.values.tolist())

# %%
fig, ax = plt.subplots(figsize = (15, 7))
for region in region_list:
    new_df[new_df['region'] == region].plot(x='year', y='success', ax=ax, label=region)
plt.show()

# %%
df_party_ct_gb = df_combined[['party', 'success', 'num_killed_wounded']].groupby('party', as_index = False).count()
df_party_ct_gb.iloc[0]
# Out:
# party                 Democratic
# success                    98947
# num_killed_wounded         98947
# Name: 0, dtype: object

# %%
df_party_sum_gb = df_combined[['party', 'success', 'num_killed_wounded']].groupby('party', as_index = False).sum()
df_party_sum_gb
# Out:
#         party  success  num_killed_wounded
# 0  Democratic    87007            496373.0
# 1  Republican    56782            324698.0

# %%
dem_kw = df_party_sum_gb.iloc[0]['num_killed_wounded'] / df_party_ct_gb.iloc[0]['num_killed_wounded']
dem_succcess = df_party_sum_gb.iloc[0]['success'] / df_party_ct_gb.iloc[0]['success']
rep_kw = df_party_sum_gb.iloc[1]['num_killed_wounded'] / df_party_ct_gb.iloc[1]['num_killed_wounded']
rep_success = df_party_sum_gb.iloc[1]['success'] / df_party_ct_gb.iloc[1]['success']

# %%
print('Democratic Killed or Wounded', dem_kw)
print('Republican Killed or Wounded', rep_kw)
print('----')
print('Democratic Sucessful Attacks', dem_succcess)
print('Republican Sucessful Attacks', rep_success)
# Out:
# Democratic Killed or Wounded 5.01655431696
# Republican Killed or Wounded 5.30743077577
# ----
# Democratic Sucessful Attacks 0.879329337928
# Republican Sucessful Attacks 0.92814410409

# %%
plt.figure(figsize = (9, 5))
x = np.arange(2)
kw_values = [dem_succcess, rep_success]
plt.bar(x, kw_values)
plt.xticks(x, ('Dem', 'Rep'))
plt.xlabel('Party', fontsize = 14)
plt.ylabel('Number Killed \nor\n Wounded \n (normalized per event)', fontsize = 14)
plt.title('Number of People Killed or Wounded As a Function of US President', fontsize = 14)
for a, b in zip(x, kw_values):
    plt.text(a, b, str(b))
plt.show()

# %%
dem_success = df_combined[df_combined['party'] == 'Democratic']['num_killed_wounded'].tolist()
rep_success = df_combined[df_combined['party'] == 'Republician']['num_killed_wounded'].tolist()

# %%
dem_success = df_combined[df_combined['party'] == 'Democratic']
dem_success.describe()['num_killed_wounded']
# Out:
# count    98947.000000
# mean         5.016554
# std         28.543365
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          4.000000
# max       5513.000000
# Name: num_killed_wounded, dtype: float64

# %%
rep_success = df_combined[df_combined['party'] == 'Republican']
rep_success.describe()['num_killed_wounded']
# Out:
# count    61178.000000
# mean         5.307431
# std         53.769876
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          3.000000
# max       8749.000000
# Name: num_killed_wounded, dtype: float64

# %%
mean1 = rep_success.describe()['num_killed_wounded']['mean']
std1 = rep_success.describe()['num_killed_wounded']['std']
n1 = rep_success.describe()['num_killed_wounded']['count']
mean2 = dem_success.describe()['num_killed_wounded']['mean']
std2 = dem_success.describe()['num_killed_wounded']['std']
n2 = dem_success.describe()['num_killed_wounded']['count']

# %%
tstat, pvalue = ttest_ind_from_stats(mean1, std1, n1, mean2, std2, n2)
pvalue
# Out:
# 0.15843932223631496

# %%
mean1, mean2
# Out:
# (5.3074307757690677, 5.0165543169575635)

# %%
tstat
# Out:
# 1.4103465498113046

# %%
df_combined_gb = df_combined[['success', 'type_of_weapon','region']].groupby(['region', 'type_of_weapon'], as_index = True).sum()

# %%
df_combined_gb.head()
# Out:
#                                                  success
# region                type_of_weapon
# Australasia & Oceania Chemical                         2
#                       Explosives/Bombs/Dynamite       63
#                       Firearms                        64
#                       Incendiary                      68
#                       Melee                            8

# %%
labels = df_combined_gb.loc['Australasia & Oceania'].index.values.tolist()
values = df_combined_gb.loc['Australasia & Oceania']['success'].tolist()
plt.pie(values, labels = None)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), labels = labels)
plt.title('Mode of Attack for Australasia & Oceania')
plt.axis('equal')
plt.show()

# %%
df_bomb = df_combined[df_combined['type_of_attack'] == 'Bombing/Explosion']
df_bomb_gb = df_bomb[['year', 'success']].groupby('year', as_index = False).sum()
x = df_bomb_gb['year']
y = df_bomb_gb['success']
plt.plot(x, y)
plt.show()

# %%
df_combined_ct = pd.crosstab(df_combined.year, df_combined.type_of_attack)
df_combined_ct.plot(figsize=(15,8), alpha = 1, linewidth=3)
plt.ylabel('Number of Successful Attacks', fontsize = 14)
plt.xlabel('Year', fontsize = 14)
plt.title('Number of Attacks Per Year', fontsize = 14)
plt.show()

# %%
#Determine the number of sucessful attacks by country

df_combined_country_gb = df[['success', 'country']].groupby(['country'], as_index = False).sum()
df_combined_country_gb.sort_values('success', ascending=False).head()
# Out:
#          country  success
# 84          Iraq    20075
# 134     Pakistan    12032
# 0    Afghanistan    10023
# 80         India     9480
# 35      Colombia     7574

# %%
df_combined_country_gb.sort_values('success', ascending=False).tail()
# Out:
#           country  success
# 126  New Hebrides        1
# 131   North Korea        1
# 24         Brunei        0
# 193  Vatican City        0
# 115     Mauritius        0

# %%
#Determine the total number of attacks by type.

df_combined_type_gb = df_combined[['type_of_attack', 'success']].groupby(['type_of_attack'], as_index =False).count()
df_combined_type_gb = df_combined_type_gb.sort_values(by=['success'], ascending=False)

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x = 'type_of_attack', y = 'success', data = df_combined_type_gb)
plt.xticks(rotation=90)
plt.xlabel('Type of Attack', fontsize = 14)
plt.ylabel('Number of Attacks', fontsize = 14)
plt.title('Number of Attacks by Type', fontsize = 14)
plt.savefig('Figure2.png')
plt.grid(True)
plt.show()

# %%
df_kidnapping = df_combined[df_combined['type_of_attack'] == 'Hostage Taking (Kidnapping)']
df_kidnapping = df_kidnapping[['country', 'success']].groupby(['country']).count()

# %%
df_bombing = df_combined[df_combined['type_of_attack'] == 'Bombing/Explosion']
df_bombing = df_bombing[['type_of_attack', 'region']].groupby('region', as_index=False).count()

# %%
labels = df_bombing['region'].tolist()
sizes = df_bombing['type_of_attack'].tolist()

# %%
squarify.plot(sizes=sizes, label=labels, alpha=.4 )
plt.axis('off')
plt.title('Type of Attack By Region (Bombing/Explosions)')
plt.show()

# %%
len(df_bombing['region'].tolist())
# Out:
# 12

# %%
df_kidnapping = df_combined[df_combined['type_of_attack'] == 'Hostage Taking (Kidnapping)']
df_kidnapping = df_kidnapping[['country', 'success']].groupby(['country'], as_index=False).count()

# %%
df_kidnapping = df_kidnapping.sort_values('success', ascending=False).head(10)
df_kidnapping
# Out:
#          country  success
# 45         India     1075
# 24      Colombia     1031
# 0    Afghanistan      898
# 47          Iraq      828
# 77      Pakistan      781
# 82   Philippines      543
# 76       Nigeria      381
# 61         Libya      378
# 110        Yemen      350
# 89       Somalia      315

# %%
df_target_gb = df_combined[['type_of_target', 'success']].groupby(['type_of_target'], as_index =False).count()
df_target_gb.sort_values(by=['success'], ascending=False).head(10)
# Out:
#                     type_of_target  success
# 13     Private Citizens & Property    37219
# 9                         Military    23758
# 12                          Police    21710
# 6             Government (General)    19170
# 2                         Business    19019
# 18                  Transportation     6208
# 20                       Utilities     5680
# 19                         Unknown     4672
# 3          Educational Institution     3996
# 14  Religious Figures/Institutions     3816

# %%
#Calculate the total number of attacks by year

df_year_gb = df_combined[['year', 'success']].groupby(['year'], as_index = False).sum()
df_year_10 = df_year_gb.sort_values(by=['success'], ascending = False).head(10)

# %%
plt.figure(figsize=(6, 6))
sns.set_style('whitegrid')
ax = sns.barplot(x='year', y='success', data = df_year_10)
plt.grid(True)
plt.xlabel('Year', fontsize = 14)
plt.ylabel('Total Number of Attacks', fontsize = 14)
plt.title('Years With Most Terror Attacks', fontsize = 14)
plt.show()

# %%
#Calculate the total number of attacks by month

df_month_gb = df_combined[['month', 'success']].groupby(['month'], as_index = False).sum()
df_month_gb = df_month_gb.sort_values(by=['success'], ascending = False)
df_month_gb
# Out:
#     month  success
# 5       5    13461
# 7       7    12967
# 10     10    12337
# 8       8    12308
# 3       3    12133
# 6       6    12046
# 4       4    11941
# 1       1    11898
# 11     11    11711
# 9       9    11284
# 2       2    10958
# 12     12    10726
# 0       0       19

# %%
#Calculate the total number of attacks by region

df_country_gb = df_combined[['region', 'success']].groupby(['region'], as_index = False).sum()
df_country_gb.sort_values(by=['success'], ascending = False).head()
# Out:
#                         region  success
# 5   Middle East & North Africa    37185
# 8                   South Asia    36694
# 7                South America    16919
# 11              Western Europe    13463
# 10          Sub-Saharan Africa    13454

# %%
df_columbia = df_combined[df_combined['country'] == 'Colombia']
df_columbia.columns.tolist()
# Out:
# ['year',
#  'month',
#  'day',
#  'country',
#  'region',
#  'city',
#  'latitude',
#  'longitude',
#  'location',
#  'success',
#  'sucide',
#  'type_of_attack',
#  'type_of_target',
#  'nationality',
#  'group_name',
#  'type_of_weapon',
#  'num_killed',
#  'num_wounded',
#  'num_killed_wounded',
#  'president',
#  'party',
#  'code',
#  'helper',
#  'country_name',
#  'gdp_value']

# %%
df_columbia[['success', 'type_of_attack']].groupby('type_of_attack', as_index = False).count()
# Out:
#                         type_of_attack  success
# 0                        Armed Assault     1933
# 1                        Assassination     1331
# 2                    Bombing/Explosion     3075
# 3       Facility/Infrastructure Attack      266
# 4                            Hijacking       32
# 5  Hostage Taking (Barricade Incident)       88
# 6          Hostage Taking (Kidnapping)     1031
# 7                      Unarmed Assault       14
# 8                              Unknown      393

# %%
df_columbia = df_columbia[['year', 'success']].groupby(['year'], as_index = False).sum()

# %%
plt.figure(figsize = (5, 5))
x = df_columbia['year']
y = df_columbia['success']
plt.plot(x, y)
plt.show()

# %%
df_columbia = df_combined[df_combined['country'] == 'Colombia']

df_columbia = df_columbia[['year', 'success', 'gdp_value']].groupby(['year'],as_index=False).sum()

# %%
x = df_columbia['year']
y1 = df_columbia['success']
y2 = df_columbia['gdp_value']
fig, ax1 = plt.subplots(figsize = (8, 8))
ax1.plot(x, y1, c='r', linewidth = 3)
ax1.set_ylabel('Number of Sucessful Attacks \nIn Columbia', fontsize = 14)
ax2 = ax1.twinx()
ax2.plot(x, y2, c='b', linewidth = 3)
ax2.set_ylabel('GDP Values (US $)', fontsize = 14)
ax1.set_xlabel('Year', fontsize = 14)
plt.title('GDP Values and Number of Sucessful Attacks in Columbia', fontsize = 14)
plt.savefig('Figure3.png')
plt.legend()
plt.show()

# %%
df_iraq = df_combined[df_combined['country'] == 'Iraq'].reset_index(drop=True)
df_iraq.head()
# Out:
#    year  month  day country                      region     city  latitude  \
# 0  1975      3    1    Iraq  Middle East & North Africa    Mosul     36.34
# 1  1976     12   15    Iraq  Middle East & North Africa  Baghdad     33.30
# 2  1976     12   18    Iraq  Middle East & North Africa  Penjwon       NaN
# 3  1976     12   24    Iraq  Middle East & North Africa  Baghdad     33.30
# 4  1979      6   15    Iraq  Middle East & North Africa    Basra     30.50
#
#    longitude location  success      ...                  type_of_weapon  \
# 0  43.130000      NaN        1      ...                         Unknown
# 1  44.400000      NaN        1      ...       Explosives/Bombs/Dynamite
# 2        NaN      NaN        1      ...                         Unknown
# 3  44.400000      NaN        1      ...                        Firearms
# 4  47.816667      NaN        1      ...                         Unknown
#
#   num_killed num_wounded num_killed_wounded     president       party  code  \
# 0        0.0         1.0                1.0   Gerald Ford  Republican    IQ
# 1       10.0       285.0              295.0   Gerald Ford  Republican    IQ
# 2        0.0         0.0                0.0   Gerald Ford  Republican    IQ
# 3        2.0         0.0                2.0   Gerald Ford  Republican    IQ
# 4        1.0         0.0                1.0  Jimmy Carter  Democratic    IQ
#
#    helper  country_name     gdp_value
# 0  IQ1975          Iraq  1.345852e+10
# 1  IQ1976          Iraq  1.775483e+10
# 2  IQ1976          Iraq  1.775483e+10
# 3  IQ1976          Iraq  1.775483e+10
# 4  IQ1979          Iraq  3.781646e+10
#
# [5 rows x 25 columns]

# %%
df_iraq_year = df_iraq[['year', 'success']].groupby(['year'],as_index=False).sum()
df_iraq_year[df_iraq_year['year'] > 2000]
plt.figure(figsize=(10, 10))
x = df_iraq_year['year']
y = df_iraq_year['success']
plt.plot(x, y, alpha = 0.5)
plt.ylabel('Number of Successful Attacks Per Year', fontsize = 14)
plt.xlabel('Year', fontsize = 14)
plt.title('Number of Successful Attacks Per Year (Iraq)', fontsize = 14)
plt.xlim(1970, 2020)
plt.show()

# %%
df_iraq_city_gb = df_iraq[['city', 'success']].groupby('city', as_index=False).sum()
df_iraq_city_gb.sort_values(by=['success'], ascending=False).head()
# Out:
#          city  success
# 351   Baghdad     6888
# 829     Mosul     1603
# 744    Kirkuk      813
# 371   Baqubah      679
# 486  Fallujah      500

# %%
x = df_iraq['year']
y = df_iraq['gdp_value']
plt.plot(x, y)
plt.show()

# %%
df_iraq_2000_2016 = df_iraq[df_iraq['year'] > 2000].reset_index(drop=True)
x = df_iraq_2000_2016['year']
y = df_iraq_2000_2016['gdp_value']

# %%
df_iraq_year = df_iraq[['year', 'success', 'gdp_value']].groupby(['year'],as_index=False).sum()
df_iraq_year_2000_2016 = df_iraq_year[df_iraq_year['year'] > 2000].reset_index(drop=True)
df_iraq_year_2000_2016 = df_iraq_year_2000_2016.fillna(0)

# %%
df_iraq_year_2000_2016
# Out:
#     year  success     gdp_value
# 0   2001        3  0.000000e+00
# 1   2002        4  0.000000e+00
# 2   2003       80  0.000000e+00
# 3   2004      310  1.172093e+13
# 4   2005      599  3.087212e+13
# 5   2006      824  5.452243e+13
# 6   2007     1038  9.301553e+13
# 7   2008     1053  1.454335e+14
# 8   2009     1056  1.269586e+14
# 9   2010     1073  1.633115e+14
# 10  2011     1183  2.429610e+14
# 11  2012     1389  3.132674e+14
# 12  2013     2671  6.685122e+14
# 13  2014     3649  9.212280e+14
# 14  2015     2365  4.929322e+14
# 15  2016     2629  5.755171e+14

# %%
x = df_iraq_year_2000_2016['year']
y1 = df_iraq_year_2000_2016['success']
y2 = df_iraq_year_2000_2016['gdp_value']

fig, ax1 = plt.subplots(figsize = (8, 8))
ax1.plot(x, y1, c='r', linewidth = 3)
ax1.set_ylabel('Number of Sucessful Attacks In Iraq', fontsize = 14)
ax2 = ax1.twinx()
ax2.plot(x, y2, c='b', linewidth = 3)
ax2.set_ylabel('GDP Values', fontsize = 14)
ax1.set_xlabel('Year', fontsize = 14)
plt.title('GDP Values and Number of Sucessful Attacks in Iraq', fontsize = 14)
plt.legend()
plt.show()

# %%
df_iraq.corr()
# Out:
#                         year     month       day  latitude  longitude  \
# year                1.000000 -0.023877  0.032349  0.039087  -0.165203
# month              -0.023877  1.000000  0.016606  0.012473  -0.013136
# day                 0.032349  0.016606  1.000000  0.004110  -0.008637
# latitude            0.039087  0.012473  0.004110  1.000000  -0.518664
# longitude          -0.165203 -0.013136 -0.008637 -0.518664   1.000000
# success            -0.131492 -0.014316 -0.016286 -0.039529   0.150974
# sucide             -0.021563 -0.003371  0.007688  0.049071  -0.106990
# num_killed         -0.027539 -0.001983 -0.002996  0.012454  -0.037507
# num_wounded        -0.095995 -0.002370  0.001312 -0.052586   0.040615
# num_killed_wounded -0.081997 -0.002713 -0.000662 -0.030359   0.008706
# gdp_value           0.726901  0.012756  0.047261  0.123895  -0.122191
#
#                      success    sucide  num_killed  num_wounded  \
# year               -0.131492 -0.021563   -0.027539    -0.095995
# month              -0.014316 -0.003371   -0.001983    -0.002370
# day                -0.016286  0.007688   -0.002996     0.001312
# latitude           -0.039529  0.049071    0.012454    -0.052586
# longitude           0.150974 -0.106990   -0.037507     0.040615
# success             1.000000 -0.078691    0.029410     0.078911
# sucide             -0.078691  1.000000    0.168874     0.208212
# num_killed          0.029410  0.168874    1.000000     0.305848
# num_wounded         0.078911  0.208212    0.305848     1.000000
# num_killed_wounded  0.070983  0.235529    0.743349     0.864202
# gdp_value          -0.031522 -0.088614   -0.048183    -0.097045
#
#                     num_killed_wounded  gdp_value
# year                         -0.081997   0.726901
# month                        -0.002713   0.012756
# day                          -0.000662   0.047261
# latitude                     -0.030359   0.123895
# longitude                     0.008706  -0.122191
# success                       0.070983  -0.031522
# sucide                        0.235529  -0.088614
# num_killed                    0.743349  -0.048183
# num_wounded                   0.864202  -0.097045
# num_killed_wounded            1.000000  -0.093702
# gdp_value                    -0.093702   1.000000

# %%
df_iraq_attack_type = df_iraq[['type_of_attack', 'success']].groupby(['type_of_attack'], as_index=False).count()
df_iraq_attack_type.sort_values(by=['success'], ascending=False).reset_index(drop=True)
# Out:
#                         type_of_attack  success
# 0                    Bombing/Explosion    16399
# 1                        Armed Assault     2959
# 2                        Assassination     1233
# 3          Hostage Taking (Kidnapping)      828
# 4                              Unknown      544
# 5       Facility/Infrastructure Attack      131
# 6  Hostage Taking (Barricade Incident)       22
# 7                            Hijacking       10
# 8                      Unarmed Assault        4

# %%
df_iraq[['city', 'success', 'year']].groupby(['city', 'year'], as_index = False).sum().sort_values(by='success', ascending=False).head()
# Out:
#         city  year  success
# 544  Baghdad  2015      951
# 545  Baghdad  2016      938
# 543  Baghdad  2014      855
# 542  Baghdad  2013      616
# 539  Baghdad  2010      552

# %%
df_baghdad = df_iraq[df_iraq['city'] == 'Baghdad']
df_baghdad_gb = df_baghdad[['group_name', 'success']].groupby('group_name', as_index=False).sum()
df_baghdad_gb.sort_values(by='success', ascending=False).head()
# Out:
#                                      group_name  success
# 53                                      Unknown     5923
# 26  Islamic State of Iraq and the Levant (ISIL)      556
# 6                              Al-Qaida in Iraq      210
# 25                  Islamic State of Iraq (ISI)       54
# 52                             Tawhid and Jihad       19

# %%
df_isis = df_iraq[df_iraq['group_name'] == 'Islamic State of Iraq and the Levant (ISIL)'].reset_index()
df_isis[['city', 'success']].groupby('city', as_index=False).sum().sort_values(by='success', ascending=False).head()
# Out:
#               city  success
# 144        Baghdad      556
# 347          Mosul      282
# 394         Ramadi      117
# 185  Dawr district      106
# 199       Fallujah       91

# %%
df_isis[['type_of_target', 'success']].groupby('type_of_target', 
                                               as_index=False).sum().sort_values(by='success', 
                                                                                 ascending=False).head()
# Out:
#                   type_of_target  success
# 11   Private Citizens & Property     1360
# 7                       Military      649
# 10                        Police      454
# 1                       Business      169
# 13  Terrorists/Non-State Militia      123

# %%
plt.figure(figsize=(10, 10))
df_usa = df_combined[df_combined['country'] == 'United States']
df_usa_gb = df_usa[['year', 'success']].groupby('year', as_index=False).sum()
x = df_usa_gb['year']
y = df_usa_gb['success']
plt.xlabel('Year', fontsize = 14)
plt.ylabel('Number of Successful Terror Attacks', fontsize = 14)
plt.plot(x, y)
plt.show()

# %%
df_usa = df_combined[df_combined['country'] == 'United States']
df_usa[['city', 'success']].groupby('city', as_index=False).sum().sort_values(by='success', ascending=False).head()
# Out:
#               city  success
# 428  New York City      353
# 551       San Juan      101
# 351    Los Angeles       95
# 547  San Francisco       79
# 387          Miami       77

# %%
df_losangeles = df_usa[df_usa['city'] == 'Los Angeles']
df_losangeles[['year', 
               'success']].groupby('year', 
                                           as_index=False).sum().sort_values(by='success', 
                                                                             ascending=False).head()
cross_la = pd.crosstab(df_losangeles.year, df_losangeles.type_of_attack)
cross_la.plot()
plt.show()

# %%
df_nyc = df_usa[df_usa['city'] == 'New York City']
df_nyc[['year', 
               'success']].groupby('year', 
                                           as_index=False).sum().sort_values(by='success', 
                                                                             ascending=False).head()
cross_nyc = pd.crosstab(df_nyc.year, df_nyc.type_of_attack)
cross_nyc.plot()
plt.show()

# %%
df_combined.groupby('country')

# %%
x = df_combined[['year', 'country', 'success']].groupby(['country', 'year'], as_index = False).sum()

# %%
#http://jonathansoma.com/lede/data-studio/classes/small-multiples/long-explanation-of-using-plt-subplots-to-create-small-multiples/

plt.figure(figsize=(20, 40), facecolor = 'white')

plot_num = 1

for country_name, selection in x.groupby(['country']):
    ax = plt.subplot(15, 11, plot_num)
    selection.plot(x= 'year', y='success', ax=ax, label = country_name, legend = False)
    ax.set_title(country_name)
    plot_num += 1
plt.tight_layout()
plt.show()
# Out:
# /Users/gta/dev/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2918: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1974.0, right=1974.0
#   'left=%s, right=%s') % (left, right))
# /Users/gta/dev/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2918: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1992.0, right=1992.0
#   'left=%s, right=%s') % (left, right))
# /Users/gta/dev/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2918: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1995.0, right=1995.0
#   'left=%s, right=%s') % (left, right))
# /Users/gta/dev/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2918: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1981.0, right=1981.0
#   'left=%s, right=%s') % (left, right))
# /Users/gta/dev/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2918: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1996.0, right=1996.0
#   'left=%s, right=%s') % (left, right))

# %%
y = df_combined[['year', 'region', 'success']].groupby(['region', 'year'], as_index = False).sum()

# %%
plt.figure(figsize=(15, 10), facecolor = 'white')

plot_num = 1

for country_name, selection in y.groupby(['region']):
    ax = plt.subplot(4, 3, plot_num)
    selection.plot(x= 'year', y='success', ax=ax, label = country_name, legend = False)
    ax.set_title(country_name)
    plot_num += 1
plt.tight_layout()
plt.show()
