# %%
#Standard imports 

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json
import requests as r
# %matplotlib inline

# %%
file = 'Success Rates by Country by Year.csv'

# %%
df = pd.read_csv(file,index_col=0)

# %%
df.head()
# Out:
#        country  year  success_rate  num_attacks
# 0  Afghanistan  1973           0.0            1
# 1  Afghanistan  1979           1.0            3
# 2  Afghanistan  1987           1.0            1
# 3  Afghanistan  1988           1.0           11
# 4  Afghanistan  1989           0.6           10

# %%
afghan = df[df['country'] =='Afghanistan']
afghan
# Out:
#         country  year  success_rate  num_attacks
# 0   Afghanistan  1973      0.000000            1
# 1   Afghanistan  1979      1.000000            3
# 2   Afghanistan  1987      1.000000            1
# 3   Afghanistan  1988      1.000000           11
# 4   Afghanistan  1989      0.600000           10
# 5   Afghanistan  1990      1.000000            2
# 6   Afghanistan  1991      1.000000           30
# 7   Afghanistan  1992      0.805556           36
# 8   Afghanistan  1994      1.000000            9
# 9   Afghanistan  1995      0.833333            6
# 10  Afghanistan  1996      0.750000            4
# 11  Afghanistan  1997      1.000000            1
# 12  Afghanistan  1998      1.000000            1
# 13  Afghanistan  1999      1.000000            9
# 14  Afghanistan  2000      1.000000           14
# 15  Afghanistan  2001      1.000000           14
# 16  Afghanistan  2002      0.736842           38
# 17  Afghanistan  2003      0.930000          100
# 18  Afghanistan  2004      0.897727           88
# 19  Afghanistan  2005      0.967742          155
# 20  Afghanistan  2006      0.968085          282
# 21  Afghanistan  2007      0.985294          340
# 22  Afghanistan  2008      0.930120          415
# 23  Afghanistan  2009      0.948207          502
# 24  Afghanistan  2010      0.916821          541
# 25  Afghanistan  2011      0.942993          421
# 26  Afghanistan  2012      0.915531         1468
# 27  Afghanistan  2013      0.923664         1441
# 28  Afghanistan  2014      0.913234         1821
# 29  Afghanistan  2015      0.844318         1927
# 30  Afghanistan  2016      0.747368         1615

# %%
plt.plot(afghan['year'],afghan['success_rate'])
